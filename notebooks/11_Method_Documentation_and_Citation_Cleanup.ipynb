# %% [markdown]
# # 11 Method Documentation and Citation Cleanup
#
# Generate method documentation tables and track citation cleanup before submission.

# %%
from pathlib import Path
import pandas as pd

REPO_ROOT = Path('..').resolve()
DOC_DIR = REPO_ROOT / 'reports' / 'method_documentation'
DOC_DIR.mkdir(parents=True, exist_ok=True)
active_citation_decisions = pd.DataFrame([
    {'key': 'Autoencoders', 'decision': 'keep temporarily; replace with book-chapter metadata if identified'},
    {'key': 'AEIntroduction', 'decision': 'remove from active use'},
    {'key': 'BottleneckRepresentation', 'decision': 'remove unless redundancy penalty is discussed'},
    {'key': 'BottleneckInvestigation', 'decision': 'keep only for bottleneck-size discussion'},
    {'key': 'Hyper-Parameter', 'decision': 'keep only if Smith procedure guided training'},
])
active_citation_decisions

# %% [markdown]
# ## Experiment Steps
#
# Fill in the executable experiment cells here. Outputs should be written under reports/ so later notebooks can consume them.
