# %% [markdown]
# # 07 VER Ablation and Sensitivity
#
# Compare global MSE, global MAE, VER max, VER top-k, and sensitivity to segment count/width.

# %%
from pathlib import Path
import itertools
import numpy as np
import pandas as pd

REPO_ROOT = Path('..').resolve()
SCORE_DIR = REPO_ROOT / 'reports' / 'scores'
ABLATION_DIR = REPO_ROOT / 'reports' / 'ablations'
ABLATION_DIR.mkdir(parents=True, exist_ok=True)
SEGMENT_COUNTS = [5, 10, 15, 20]
OVERLAPS = [0.0, 0.5]
TOP_K_VALUES = [1, 3, 5]
experiment_grid = pd.DataFrame(list(itertools.product(SEGMENT_COUNTS, OVERLAPS, TOP_K_VALUES)), columns=['n_segments', 'overlap', 'top_k'])
experiment_grid

# %% [markdown]
# ## Experiment Steps
#
# Fill in the executable experiment cells here. Outputs should be written under reports/ so later notebooks can consume them.
