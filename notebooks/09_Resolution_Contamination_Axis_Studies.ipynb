# %% [markdown]
# # 09 Resolution Contamination Axis Studies
#
# Run resolution, training-contamination, and single-axis versus three-axis robustness experiments.

# %%
from pathlib import Path
import itertools
import pandas as pd

REPO_ROOT = Path('..').resolve()
ROBUSTNESS_DIR = REPO_ROOT / 'reports' / 'robustness'
ROBUSTNESS_DIR.mkdir(parents=True, exist_ok=True)
RESOLUTIONS = [(75, 50), (150, 100), (300, 200)]
CONTAMINATION_FRACTIONS = [0.01, 0.02, 0.05, 0.10]
AXIS_MODES = ['x', 'y', 'z', 'xyz_rgb']
resolution_grid = pd.DataFrame(RESOLUTIONS, columns=['width', 'height'])
contamination_grid = pd.DataFrame({'fraction': CONTAMINATION_FRACTIONS})
axis_grid = pd.DataFrame({'axis_mode': AXIS_MODES})
display(resolution_grid, contamination_grid, axis_grid)

# %% [markdown]
# ## Experiment Steps
#
# Fill in the executable experiment cells here. Outputs should be written under reports/ so later notebooks can consume them.
