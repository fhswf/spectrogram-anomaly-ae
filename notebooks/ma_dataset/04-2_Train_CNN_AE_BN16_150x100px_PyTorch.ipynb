# %% [markdown]
# # Autoencoder Training
#
# This notebook trains a convolutional autoencoder on **normal data** (no chatter).
# The model learns a compact representation and attempts to reconstruct the input images.
# Because anomalous samples (chatter) are not seen during training, we expect them to yield a **higher reconstruction error**.
#
# **Core idea:** anomaly score = reconstruction error (e.g., MSE) between the input and its reconstruction.

# %%
import os
import random
import numpy as np
from PIL import Image
from tqdm import tqdm
import plotly.express as px 

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

# %%
SEED = 42

os.environ["PYTHONHASHSEED"] = str(SEED)

random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# GPU check
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

if torch.cuda.is_available():
    print(f"GPU detected: {torch.cuda.get_device_name(0)}")
else:
    print("No GPU found.")
# Out:
# No GPU found.

# %% [markdown]
# ## Data
#
# The spectrograms are loaded as images.
#
# We distinguish between:
# - **GOOD / Normal**: samples without chatter (used for training)
# - **BAD / Chatter**: potentially anomalous samples (typically used for evaluation)
#
# This notebook trains the autoencoder using **only the normal (GOOD)** class.

# %%
#DATA_GOOD = "../data/02_spectrograms_150x100px_dataset/train/no_chatter"
DATA_GOOD = "../../data/03_broach_dataset/train/"

# %%
def load_images_from_folder(folder, target_size=(150, 100)):
    images = []
    valid_ext = (".png", ".jpg", ".jpeg")

    for file in tqdm(os.listdir(folder)):
        if file.lower().endswith(valid_ext):
            path = os.path.join(folder, file)

            img = (
                Image.open(path)
                .convert("RGB")
                .resize(target_size)
            )

            images.append(np.array(img))

    return np.array(images)

# %% [markdown]
# Load only normal data!

# %%
images = load_images_from_folder(DATA_GOOD)

images = images.astype(np.float32) / 255.0

print("Loaded normal samples:", images.shape)

x_train, x_val = train_test_split(
    images,
    test_size=0.2,
    random_state=SEED,
    shuffle=True
)

print("Train:", x_train.shape)
print("Val:", x_val.shape)

# NHWC -> NCHW
x_train = np.transpose(x_train, (0, 3, 1, 2))
x_val = np.transpose(x_val, (0, 3, 1, 2))

print("PyTorch shape:", x_train.shape)
# Out:
# 100%|██████████| 5000/5000 [05:43<00:00, 14.56it/s]
# Loaded normal samples: (5000, 100, 150, 3)
# Train: (4000, 100, 150, 3)
# Val: (1000, 100, 150, 3)
# PyTorch shape: (4000, 3, 100, 150)

# %% [markdown]
# ## Visualization / Sanity Check
#
# To verify the data pipeline, we visualize one example spectrogram from the training set.
# This helps confirm that resizing and normalization behave as expected.

# %%
img = x_train[1120].transpose(1, 2, 0)

fig = px.imshow(img)
fig.update_layout(coloraxis_showscale=False)
fig.show()

# %% [markdown]
# ## Model: Convolutional Autoencoder
#
# The autoencoder consists of three parts:
#
# 1. **Encoder**: extracts features using convolutions and progressively reduces spatial dimensions
# 2. **Bottleneck**: compresses the representation using a dense layer
# 3. **Decoder**: reconstructs the input via dense expansion, reshaping, upsampling, and convolutions
#
# ### Training objective
# The model minimizes the reconstruction error (MSE) between the input image $x$ and its reconstruction $\hat{x}$.
#
# During anomaly detection, the reconstruction error is used as an anomaly score.

# %%
# Dataloader 
batch_size = 1024

train_dataset = TensorDataset(torch.tensor(x_train))
val_dataset = TensorDataset(torch.tensor(x_val))

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False
)

# %%
class Autoencoder(nn.Module):

    def __init__(self):
        super().__init__()

        # Encoder
        self.encoder_conv = nn.Sequential(
            nn.Conv2d(3, 4, kernel_size=3, padding=1),
            nn.ReLU(),

            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(4, 8, kernel_size=3, padding=1),
            nn.ReLU(),

            nn.MaxPool2d(kernel_size=(2, 3), stride=(2, 3)),

            nn.Conv2d(8, 12, kernel_size=3, padding=1),
            nn.ReLU()
        )

        self.flatten = nn.Flatten()

        self.encoder_fc = nn.Sequential(
            nn.Linear(12 * 25 * 25, 16),
            nn.ReLU()
        )

        # Decoder
        self.decoder_fc = nn.Sequential(
            nn.Linear(16, 12 * 25 * 25),
            nn.ReLU()
        )

        self.decoder_conv = nn.Sequential(
            nn.Conv2d(12, 12, kernel_size=3, padding=1),
            nn.ReLU(),

            nn.Upsample(scale_factor=(2, 3), mode='nearest'),

            nn.Conv2d(12, 8, kernel_size=3, padding=1),
            nn.ReLU(),

            nn.Upsample(scale_factor=(2, 2), mode='nearest'),

            nn.Conv2d(8, 4, kernel_size=3, padding=1),
            nn.ReLU(),

            nn.Conv2d(4, 3, kernel_size=3, padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):

        x = self.encoder_conv(x)

        x = self.flatten(x)

        latent = self.encoder_fc(x)

        x = self.decoder_fc(latent)

        x = x.view(-1, 12, 25, 25)

        x = self.decoder_conv(x)

        return x

# %%
model = Autoencoder().to(device)

print(model)
# Out:
# Autoencoder(
#   (encoder_conv): Sequential(
#     (0): Conv2d(3, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=(2, 3), stride=(2, 3), padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(8, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (encoder_fc): Sequential(
#     (0): Linear(in_features=7500, out_features=16, bias=True)
#     (1): ReLU()
#   )
#   (decoder_fc): Sequential(
#     (0): Linear(in_features=16, out_features=7500, bias=True)
#     (1): ReLU()
#   )
#   (decoder_conv): Sequential(
#     (0): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Upsample(scale_factor=(2.0, 3.0), mode='nearest')
#     (3): Conv2d(12, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): Upsample(scale_factor=(2.0, 2.0), mode='nearest')
#     (6): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): Conv2d(4, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): Sigmoid()
#   )
# )

# %% [markdown]
# ## Training Setup
#
# - **Optimizer:** Adam with a small learning rate
# - **Loss:** Mean Squared Error (MSE), measuring reconstruction quality
#
# Because the autoencoder is trained on normal data only, anomalous inputs are expected to produce larger reconstruction errors.

# %%
loss='mse'
#-----------
criterion = nn.MSELoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=1e-4
)

#------------
epochs = 4000

train_losses = []
val_losses = []

for epoch in range(epochs):

    # --------------------
    # Training
    # --------------------
    model.train()

    running_loss = 0.0

    for (batch,) in train_loader:

        batch = batch.to(device)

        optimizer.zero_grad()

        outputs = model(batch)

        loss = criterion(outputs, batch)

        loss.backward()

        optimizer.step()

        running_loss += loss.item() * batch.size(0)

    train_loss = running_loss / len(train_loader.dataset)

    # --------------------
    # Validation
    # --------------------
    model.eval()

    running_val_loss = 0.0

    with torch.no_grad():

        for (batch,) in val_loader:

            batch = batch.to(device)

            outputs = model(batch)

            loss = criterion(outputs, batch)

            running_val_loss += loss.item() * batch.size(0)

    val_loss = running_val_loss / len(val_loader.dataset)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    if epoch % 10 == 0:
        print(
            f"Epoch [{epoch+1}/{epochs}] "
            f"Train Loss: {train_loss:.6f} "
            f"Val Loss: {val_loss:.6f}"
        )
# Out:
# Epoch [1/4000] Train Loss: 0.217475 Val Loss: 0.217081
# Epoch [11/4000] Train Loss: 0.208393 Val Loss: 0.206800
# Epoch [21/4000] Train Loss: 0.158123 Val Loss: 0.151028
# Epoch [31/4000] Train Loss: 0.021508 Val Loss: 0.015595
# Epoch [41/4000] Train Loss: 0.004028 Val Loss: 0.003972
# Epoch [51/4000] Train Loss: 0.002675 Val Loss: 0.002609
# Epoch [61/4000] Train Loss: 0.002150 Val Loss: 0.002146
# Epoch [71/4000] Train Loss: 0.002060 Val Loss: 0.002064
# Epoch [81/4000] Train Loss: 0.002033 Val Loss: 0.002038
# Epoch [91/4000] Train Loss: 0.002021 Val Loss: 0.002026
# Epoch [101/4000] Train Loss: 0.002014 Val Loss: 0.002020
# Epoch [111/4000] Train Loss: 0.002010 Val Loss: 0.002015
# Epoch [121/4000] Train Loss: 0.002006 Val Loss: 0.002012
# Epoch [131/4000] Train Loss: 0.002003 Val Loss: 0.002009
# Epoch [141/4000] Train Loss: 0.002001 Val Loss: 0.002006
# Epoch [151/4000] Train Loss: 0.001998 Val Loss: 0.002004
# Epoch [161/4000] Train Loss: 0.001996 Val Loss: 0.002002
# Epoch [171/4000] Train Loss: 0.001993 Val Loss: 0.001999
# Epoch [181/4000] Train Loss: 0.001991 Val Loss: 0.001997
# Epoch [191/4000] Train Loss: 0.001989 Val Loss: 0.001995
# Epoch [201/4000] Train Loss: 0.001988 Val Loss: 0.001994
# Epoch [211/4000] Train Loss: 0.001986 Val Loss: 0.001992
# Epoch [221/4000] Train Loss: 0.001985 Val Loss: 0.001991
# Epoch [231/4000] Train Loss: 0.001984 Val Loss: 0.001990
# Epoch [241/4000] Train Loss: 0.001983 Val Loss: 0.001989
# Epoch [251/4000] Train Loss: 0.001982 Val Loss: 0.001988
# Epoch [261/4000] Train Loss: 0.001981 Val Loss: 0.001987
# Epoch [271/4000] Train Loss: 0.001979 Val Loss: 0.001985
# Epoch [281/4000] Train Loss: 0.001976 Val Loss: 0.001983
# Epoch [291/4000] Train Loss: 0.001971 Val Loss: 0.001977
# Epoch [301/4000] Train Loss: 0.001963 Val Loss: 0.001968
# Epoch [311/4000] Train Loss: 0.001946 Val Loss: 0.001951
# Epoch [321/4000] Train Loss: 0.001911 Val Loss: 0.001914
# Epoch [331/4000] Train Loss: 0.001844 Val Loss: 0.001846
# Epoch [341/4000] Train Loss: 0.001746 Val Loss: 0.001744
# Epoch [351/4000] Train Loss: 0.001591 Val Loss: 0.001583
# Epoch [361/4000] Train Loss: 0.001417 Val Loss: 0.001412
# Epoch [371/4000] Train Loss: 0.001294 Val Loss: 0.001291
# Epoch [381/4000] Train Loss: 0.001189 Val Loss: 0.001185
# Epoch [391/4000] Train Loss: 0.001088 Val Loss: 0.001084
# Epoch [401/4000] Train Loss: 0.000998 Val Loss: 0.000995
# Epoch [411/4000] Train Loss: 0.000931 Val Loss: 0.000930
# Epoch [421/4000] Train Loss: 0.000882 Val Loss: 0.000881
# Epoch [431/4000] Train Loss: 0.000846 Val Loss: 0.000846
# Epoch [441/4000] Train Loss: 0.000819 Val Loss: 0.000820
# Epoch [451/4000] Train Loss: 0.000800 Val Loss: 0.000801
# Epoch [461/4000] Train Loss: 0.000785 Val Loss: 0.000786
# Epoch [471/4000] Train Loss: 0.000772 Val Loss: 0.000773
# Epoch [481/4000] Train Loss: 0.000760 Val Loss: 0.000762
# Epoch [491/4000] Train Loss: 0.000750 Val Loss: 0.000752
# Epoch [501/4000] Train Loss: 0.000741 Val Loss: 0.000743
# Epoch [511/4000] Train Loss: 0.000733 Val Loss: 0.000735
# Epoch [521/4000] Train Loss: 0.000726 Val Loss: 0.000728
# Epoch [531/4000] Train Loss: 0.000720 Val Loss: 0.000722
# Epoch [541/4000] Train Loss: 0.000714 Val Loss: 0.000716
# Epoch [551/4000] Train Loss: 0.000709 Val Loss: 0.000711
# Epoch [561/4000] Train Loss: 0.000705 Val Loss: 0.000707
# Epoch [571/4000] Train Loss: 0.000700 Val Loss: 0.000702
# Epoch [581/4000] Train Loss: 0.000696 Val Loss: 0.000698
# Epoch [591/4000] Train Loss: 0.000692 Val Loss: 0.000695
# Epoch [601/4000] Train Loss: 0.000689 Val Loss: 0.000691
# Epoch [611/4000] Train Loss: 0.000685 Val Loss: 0.000688
# Epoch [621/4000] Train Loss: 0.000682 Val Loss: 0.000684
# Epoch [631/4000] Train Loss: 0.000679 Val Loss: 0.000681
# Epoch [641/4000] Train Loss: 0.000676 Val Loss: 0.000678
# Epoch [651/4000] Train Loss: 0.000673 Val Loss: 0.000675
# Epoch [661/4000] Train Loss: 0.000670 Val Loss: 0.000673
# Epoch [671/4000] Train Loss: 0.000668 Val Loss: 0.000670
# Epoch [681/4000] Train Loss: 0.000666 Val Loss: 0.000668
# Epoch [691/4000] Train Loss: 0.000663 Val Loss: 0.000665
# Epoch [701/4000] Train Loss: 0.000661 Val Loss: 0.000663
# Epoch [711/4000] Train Loss: 0.000659 Val Loss: 0.000661
# Epoch [721/4000] Train Loss: 0.000656 Val Loss: 0.000659
# Epoch [731/4000] Train Loss: 0.000654 Val Loss: 0.000657
# Epoch [741/4000] Train Loss: 0.000652 Val Loss: 0.000654
# Epoch [751/4000] Train Loss: 0.000650 Val Loss: 0.000653
# Epoch [761/4000] Train Loss: 0.000649 Val Loss: 0.000651
# Epoch [771/4000] Train Loss: 0.000647 Val Loss: 0.000649
# Epoch [781/4000] Train Loss: 0.000645 Val Loss: 0.000647
# Epoch [791/4000] Train Loss: 0.000644 Val Loss: 0.000646
# Epoch [801/4000] Train Loss: 0.000642 Val Loss: 0.000644
# Epoch [811/4000] Train Loss: 0.000641 Val Loss: 0.000643
# Epoch [821/4000] Train Loss: 0.000639 Val Loss: 0.000642
# Epoch [831/4000] Train Loss: 0.000638 Val Loss: 0.000640
# Epoch [841/4000] Train Loss: 0.000637 Val Loss: 0.000639
# Epoch [851/4000] Train Loss: 0.000636 Val Loss: 0.000638
# Epoch [861/4000] Train Loss: 0.000634 Val Loss: 0.000637
# Epoch [871/4000] Train Loss: 0.000633 Val Loss: 0.000636
# Epoch [881/4000] Train Loss: 0.000632 Val Loss: 0.000635
# Epoch [891/4000] Train Loss: 0.000631 Val Loss: 0.000633
# Epoch [901/4000] Train Loss: 0.000630 Val Loss: 0.000632
# Epoch [911/4000] Train Loss: 0.000629 Val Loss: 0.000631
# Epoch [921/4000] Train Loss: 0.000628 Val Loss: 0.000630
# Epoch [931/4000] Train Loss: 0.000627 Val Loss: 0.000629
# Epoch [941/4000] Train Loss: 0.000626 Val Loss: 0.000628
# Epoch [951/4000] Train Loss: 0.000625 Val Loss: 0.000627
# Epoch [961/4000] Train Loss: 0.000624 Val Loss: 0.000626
# Epoch [971/4000] Train Loss: 0.000623 Val Loss: 0.000626
# Epoch [981/4000] Train Loss: 0.000622 Val Loss: 0.000625
# Epoch [991/4000] Train Loss: 0.000621 Val Loss: 0.000624
# Epoch [1001/4000] Train Loss: 0.000621 Val Loss: 0.000623
# Epoch [1011/4000] Train Loss: 0.000620 Val Loss: 0.000622
# Epoch [1021/4000] Train Loss: 0.000619 Val Loss: 0.000621
# Epoch [1031/4000] Train Loss: 0.000618 Val Loss: 0.000620
# Epoch [1041/4000] Train Loss: 0.000617 Val Loss: 0.000620
# Epoch [1051/4000] Train Loss: 0.000616 Val Loss: 0.000619
# Epoch [1061/4000] Train Loss: 0.000616 Val Loss: 0.000618
# Epoch [1071/4000] Train Loss: 0.000615 Val Loss: 0.000617
# Epoch [1081/4000] Train Loss: 0.000614 Val Loss: 0.000616
# Epoch [1091/4000] Train Loss: 0.000613 Val Loss: 0.000615
# Epoch [1101/4000] Train Loss: 0.000612 Val Loss: 0.000615
# Epoch [1111/4000] Train Loss: 0.000611 Val Loss: 0.000614
# Epoch [1121/4000] Train Loss: 0.000610 Val Loss: 0.000613
# Epoch [1131/4000] Train Loss: 0.000610 Val Loss: 0.000612
# Epoch [1141/4000] Train Loss: 0.000609 Val Loss: 0.000611
# Epoch [1151/4000] Train Loss: 0.000608 Val Loss: 0.000610
# Epoch [1161/4000] Train Loss: 0.000607 Val Loss: 0.000609
# Epoch [1171/4000] Train Loss: 0.000606 Val Loss: 0.000608
# Epoch [1181/4000] Train Loss: 0.000605 Val Loss: 0.000608
# Epoch [1191/4000] Train Loss: 0.000604 Val Loss: 0.000607
# Epoch [1201/4000] Train Loss: 0.000603 Val Loss: 0.000606
# Epoch [1211/4000] Train Loss: 0.000602 Val Loss: 0.000605
# Epoch [1221/4000] Train Loss: 0.000601 Val Loss: 0.000604
# Epoch [1231/4000] Train Loss: 0.000601 Val Loss: 0.000603
# Epoch [1241/4000] Train Loss: 0.000599 Val Loss: 0.000602
# Epoch [1251/4000] Train Loss: 0.000598 Val Loss: 0.000601
# Epoch [1261/4000] Train Loss: 0.000597 Val Loss: 0.000600
# Epoch [1271/4000] Train Loss: 0.000596 Val Loss: 0.000599
# Epoch [1281/4000] Train Loss: 0.000595 Val Loss: 0.000597
# Epoch [1291/4000] Train Loss: 0.000594 Val Loss: 0.000596
# Epoch [1301/4000] Train Loss: 0.000593 Val Loss: 0.000595
# Epoch [1311/4000] Train Loss: 0.000591 Val Loss: 0.000594
# Epoch [1321/4000] Train Loss: 0.000591 Val Loss: 0.000593
# Epoch [1331/4000] Train Loss: 0.000589 Val Loss: 0.000591
# Epoch [1341/4000] Train Loss: 0.000587 Val Loss: 0.000590
# Epoch [1351/4000] Train Loss: 0.000586 Val Loss: 0.000589
# Epoch [1361/4000] Train Loss: 0.000584 Val Loss: 0.000587
# Epoch [1371/4000] Train Loss: 0.000583 Val Loss: 0.000585
# Epoch [1381/4000] Train Loss: 0.000581 Val Loss: 0.000583
# Epoch [1391/4000] Train Loss: 0.000579 Val Loss: 0.000583
# Epoch [1401/4000] Train Loss: 0.000577 Val Loss: 0.000580
# Epoch [1411/4000] Train Loss: 0.000576 Val Loss: 0.000579
# Epoch [1421/4000] Train Loss: 0.000573 Val Loss: 0.000577
# Epoch [1431/4000] Train Loss: 0.000571 Val Loss: 0.000574
# Epoch [1441/4000] Train Loss: 0.000568 Val Loss: 0.000570
# Epoch [1451/4000] Train Loss: 0.000565 Val Loss: 0.000568
# Epoch [1461/4000] Train Loss: 0.000565 Val Loss: 0.000566
# Epoch [1471/4000] Train Loss: 0.000559 Val Loss: 0.000561
# Epoch [1481/4000] Train Loss: 0.000554 Val Loss: 0.000558
# Epoch [1491/4000] Train Loss: 0.000551 Val Loss: 0.000555
# Epoch [1501/4000] Train Loss: 0.000547 Val Loss: 0.000548
# Epoch [1511/4000] Train Loss: 0.000541 Val Loss: 0.000545
# Epoch [1521/4000] Train Loss: 0.000535 Val Loss: 0.000540
# Epoch [1531/4000] Train Loss: 0.000530 Val Loss: 0.000535
# Epoch [1541/4000] Train Loss: 0.000524 Val Loss: 0.000527
# Epoch [1551/4000] Train Loss: 0.000518 Val Loss: 0.000524
# Epoch [1561/4000] Train Loss: 0.000512 Val Loss: 0.000516
# Epoch [1571/4000] Train Loss: 0.000505 Val Loss: 0.000509
# Epoch [1581/4000] Train Loss: 0.000499 Val Loss: 0.000503
# Epoch [1591/4000] Train Loss: 0.000494 Val Loss: 0.000498
# Epoch [1601/4000] Train Loss: 0.000490 Val Loss: 0.000494
# Epoch [1611/4000] Train Loss: 0.000484 Val Loss: 0.000489
# Epoch [1621/4000] Train Loss: 0.000482 Val Loss: 0.000488
# Epoch [1631/4000] Train Loss: 0.000475 Val Loss: 0.000482
# Epoch [1641/4000] Train Loss: 0.000473 Val Loss: 0.000477
# Epoch [1651/4000] Train Loss: 0.000467 Val Loss: 0.000472
# Epoch [1661/4000] Train Loss: 0.000464 Val Loss: 0.000469
# Epoch [1671/4000] Train Loss: 0.000460 Val Loss: 0.000466
# Epoch [1681/4000] Train Loss: 0.000460 Val Loss: 0.000463
# Epoch [1691/4000] Train Loss: 0.000455 Val Loss: 0.000461
# Epoch [1701/4000] Train Loss: 0.000452 Val Loss: 0.000460
# Epoch [1711/4000] Train Loss: 0.000448 Val Loss: 0.000454
# Epoch [1721/4000] Train Loss: 0.000447 Val Loss: 0.000452
# Epoch [1731/4000] Train Loss: 0.000445 Val Loss: 0.000450
# Epoch [1741/4000] Train Loss: 0.000442 Val Loss: 0.000450
# Epoch [1751/4000] Train Loss: 0.000443 Val Loss: 0.000450
# Epoch [1761/4000] Train Loss: 0.000438 Val Loss: 0.000445
# Epoch [1771/4000] Train Loss: 0.000436 Val Loss: 0.000443
# Epoch [1781/4000] Train Loss: 0.000435 Val Loss: 0.000443
# Epoch [1791/4000] Train Loss: 0.000434 Val Loss: 0.000440
# Epoch [1801/4000] Train Loss: 0.000432 Val Loss: 0.000439
# Epoch [1811/4000] Train Loss: 0.000430 Val Loss: 0.000437
# Epoch [1821/4000] Train Loss: 0.000430 Val Loss: 0.000436
# Epoch [1831/4000] Train Loss: 0.000428 Val Loss: 0.000435
# Epoch [1841/4000] Train Loss: 0.000429 Val Loss: 0.000436
# Epoch [1851/4000] Train Loss: 0.000426 Val Loss: 0.000432
# Epoch [1861/4000] Train Loss: 0.000429 Val Loss: 0.000435
# Epoch [1871/4000] Train Loss: 0.000424 Val Loss: 0.000431
# Epoch [1881/4000] Train Loss: 0.000422 Val Loss: 0.000429
# Epoch [1891/4000] Train Loss: 0.000424 Val Loss: 0.000435
# Epoch [1901/4000] Train Loss: 0.000421 Val Loss: 0.000428
# Epoch [1911/4000] Train Loss: 0.000421 Val Loss: 0.000426
# Epoch [1921/4000] Train Loss: 0.000419 Val Loss: 0.000426
# Epoch [1931/4000] Train Loss: 0.000418 Val Loss: 0.000424
# Epoch [1941/4000] Train Loss: 0.000417 Val Loss: 0.000424
# Epoch [1951/4000] Train Loss: 0.000416 Val Loss: 0.000423
# Epoch [1961/4000] Train Loss: 0.000415 Val Loss: 0.000422
# Epoch [1971/4000] Train Loss: 0.000414 Val Loss: 0.000421
# Epoch [1981/4000] Train Loss: 0.000413 Val Loss: 0.000422
# Epoch [1991/4000] Train Loss: 0.000413 Val Loss: 0.000419
# Epoch [2001/4000] Train Loss: 0.000412 Val Loss: 0.000418
# Epoch [2011/4000] Train Loss: 0.000411 Val Loss: 0.000418
# Epoch [2021/4000] Train Loss: 0.000410 Val Loss: 0.000417
# Epoch [2031/4000] Train Loss: 0.000409 Val Loss: 0.000416
# Epoch [2041/4000] Train Loss: 0.000409 Val Loss: 0.000416
# Epoch [2051/4000] Train Loss: 0.000408 Val Loss: 0.000415
# Epoch [2061/4000] Train Loss: 0.000407 Val Loss: 0.000414
# Epoch [2071/4000] Train Loss: 0.000407 Val Loss: 0.000413
# Epoch [2081/4000] Train Loss: 0.000406 Val Loss: 0.000413
# Epoch [2091/4000] Train Loss: 0.000406 Val Loss: 0.000413
# Epoch [2101/4000] Train Loss: 0.000405 Val Loss: 0.000413
# Epoch [2111/4000] Train Loss: 0.000404 Val Loss: 0.000411
# Epoch [2121/4000] Train Loss: 0.000404 Val Loss: 0.000410
# Epoch [2131/4000] Train Loss: 0.000402 Val Loss: 0.000410
# Epoch [2141/4000] Train Loss: 0.000403 Val Loss: 0.000410
# Epoch [2151/4000] Train Loss: 0.000402 Val Loss: 0.000408
# Epoch [2161/4000] Train Loss: 0.000401 Val Loss: 0.000408
# Epoch [2171/4000] Train Loss: 0.000400 Val Loss: 0.000407
# Epoch [2181/4000] Train Loss: 0.000399 Val Loss: 0.000406
# Epoch [2191/4000] Train Loss: 0.000400 Val Loss: 0.000408
# Epoch [2201/4000] Train Loss: 0.000400 Val Loss: 0.000407
# Epoch [2211/4000] Train Loss: 0.000399 Val Loss: 0.000406
# Epoch [2221/4000] Train Loss: 0.000397 Val Loss: 0.000404
# Epoch [2231/4000] Train Loss: 0.000397 Val Loss: 0.000404
# Epoch [2241/4000] Train Loss: 0.000397 Val Loss: 0.000406
# Epoch [2251/4000] Train Loss: 0.000396 Val Loss: 0.000403
# Epoch [2261/4000] Train Loss: 0.000396 Val Loss: 0.000402
# Epoch [2271/4000] Train Loss: 0.000395 Val Loss: 0.000402
# Epoch [2281/4000] Train Loss: 0.000395 Val Loss: 0.000402
# Epoch [2291/4000] Train Loss: 0.000394 Val Loss: 0.000401
# Epoch [2301/4000] Train Loss: 0.000395 Val Loss: 0.000400
# Epoch [2311/4000] Train Loss: 0.000393 Val Loss: 0.000400
# Epoch [2321/4000] Train Loss: 0.000395 Val Loss: 0.000404
# Epoch [2331/4000] Train Loss: 0.000392 Val Loss: 0.000399
# Epoch [2341/4000] Train Loss: 0.000392 Val Loss: 0.000399
# Epoch [2351/4000] Train Loss: 0.000392 Val Loss: 0.000398
# Epoch [2361/4000] Train Loss: 0.000391 Val Loss: 0.000398
# Epoch [2371/4000] Train Loss: 0.000390 Val Loss: 0.000397
# Epoch [2381/4000] Train Loss: 0.000390 Val Loss: 0.000398
# Epoch [2391/4000] Train Loss: 0.000390 Val Loss: 0.000397
# Epoch [2401/4000] Train Loss: 0.000390 Val Loss: 0.000398
# Epoch [2411/4000] Train Loss: 0.000388 Val Loss: 0.000396
# Epoch [2421/4000] Train Loss: 0.000388 Val Loss: 0.000395
# Epoch [2431/4000] Train Loss: 0.000387 Val Loss: 0.000395
# Epoch [2441/4000] Train Loss: 0.000389 Val Loss: 0.000396
# Epoch [2451/4000] Train Loss: 0.000387 Val Loss: 0.000394
# Epoch [2461/4000] Train Loss: 0.000387 Val Loss: 0.000393
# Epoch [2471/4000] Train Loss: 0.000387 Val Loss: 0.000393
# Epoch [2481/4000] Train Loss: 0.000385 Val Loss: 0.000392
# Epoch [2491/4000] Train Loss: 0.000385 Val Loss: 0.000392
# Epoch [2501/4000] Train Loss: 0.000384 Val Loss: 0.000392
# Epoch [2511/4000] Train Loss: 0.000385 Val Loss: 0.000392
# Epoch [2521/4000] Train Loss: 0.000385 Val Loss: 0.000391
# Epoch [2531/4000] Train Loss: 0.000383 Val Loss: 0.000390
# Epoch [2541/4000] Train Loss: 0.000384 Val Loss: 0.000391
# Epoch [2551/4000] Train Loss: 0.000382 Val Loss: 0.000389
# Epoch [2561/4000] Train Loss: 0.000383 Val Loss: 0.000390
# Epoch [2571/4000] Train Loss: 0.000382 Val Loss: 0.000390
# Epoch [2581/4000] Train Loss: 0.000381 Val Loss: 0.000388
# Epoch [2591/4000] Train Loss: 0.000381 Val Loss: 0.000388
# Epoch [2601/4000] Train Loss: 0.000381 Val Loss: 0.000389
# Epoch [2611/4000] Train Loss: 0.000384 Val Loss: 0.000389
# Epoch [2621/4000] Train Loss: 0.000381 Val Loss: 0.000387
# Epoch [2631/4000] Train Loss: 0.000381 Val Loss: 0.000387
# Epoch [2641/4000] Train Loss: 0.000380 Val Loss: 0.000387
# Epoch [2651/4000] Train Loss: 0.000379 Val Loss: 0.000386
# Epoch [2661/4000] Train Loss: 0.000379 Val Loss: 0.000387
# Epoch [2671/4000] Train Loss: 0.000378 Val Loss: 0.000386
# Epoch [2681/4000] Train Loss: 0.000379 Val Loss: 0.000386
# Epoch [2691/4000] Train Loss: 0.000378 Val Loss: 0.000385
# Epoch [2701/4000] Train Loss: 0.000377 Val Loss: 0.000384
# Epoch [2711/4000] Train Loss: 0.000377 Val Loss: 0.000384
# Epoch [2721/4000] Train Loss: 0.000376 Val Loss: 0.000383
# Epoch [2731/4000] Train Loss: 0.000376 Val Loss: 0.000383
# Epoch [2741/4000] Train Loss: 0.000377 Val Loss: 0.000384
# Epoch [2751/4000] Train Loss: 0.000375 Val Loss: 0.000382
# Epoch [2761/4000] Train Loss: 0.000375 Val Loss: 0.000383
# Epoch [2771/4000] Train Loss: 0.000374 Val Loss: 0.000382
# Epoch [2781/4000] Train Loss: 0.000374 Val Loss: 0.000381
# Epoch [2791/4000] Train Loss: 0.000375 Val Loss: 0.000382
# Epoch [2801/4000] Train Loss: 0.000375 Val Loss: 0.000381
# Epoch [2811/4000] Train Loss: 0.000373 Val Loss: 0.000380
# Epoch [2821/4000] Train Loss: 0.000373 Val Loss: 0.000380
# Epoch [2831/4000] Train Loss: 0.000372 Val Loss: 0.000379
# Epoch [2841/4000] Train Loss: 0.000373 Val Loss: 0.000381
# Epoch [2851/4000] Train Loss: 0.000372 Val Loss: 0.000379
# Epoch [2861/4000] Train Loss: 0.000371 Val Loss: 0.000380
# Epoch [2871/4000] Train Loss: 0.000371 Val Loss: 0.000379
# Epoch [2881/4000] Train Loss: 0.000371 Val Loss: 0.000379
# Epoch [2891/4000] Train Loss: 0.000370 Val Loss: 0.000377
# Epoch [2901/4000] Train Loss: 0.000370 Val Loss: 0.000378
# Epoch [2911/4000] Train Loss: 0.000372 Val Loss: 0.000382
# Epoch [2921/4000] Train Loss: 0.000370 Val Loss: 0.000377
# Epoch [2931/4000] Train Loss: 0.000370 Val Loss: 0.000378
# Epoch [2941/4000] Train Loss: 0.000370 Val Loss: 0.000376
# Epoch [2951/4000] Train Loss: 0.000369 Val Loss: 0.000377
# Epoch [2961/4000] Train Loss: 0.000368 Val Loss: 0.000375
# Epoch [2971/4000] Train Loss: 0.000370 Val Loss: 0.000378
# Epoch [2981/4000] Train Loss: 0.000368 Val Loss: 0.000375
# Epoch [2991/4000] Train Loss: 0.000369 Val Loss: 0.000376
# Epoch [3001/4000] Train Loss: 0.000367 Val Loss: 0.000375
# Epoch [3011/4000] Train Loss: 0.000367 Val Loss: 0.000374
# Epoch [3021/4000] Train Loss: 0.000368 Val Loss: 0.000374
# Epoch [3031/4000] Train Loss: 0.000368 Val Loss: 0.000375
# Epoch [3041/4000] Train Loss: 0.000366 Val Loss: 0.000373
# Epoch [3051/4000] Train Loss: 0.000366 Val Loss: 0.000373
# Epoch [3061/4000] Train Loss: 0.000365 Val Loss: 0.000372
# Epoch [3071/4000] Train Loss: 0.000367 Val Loss: 0.000374
# Epoch [3081/4000] Train Loss: 0.000365 Val Loss: 0.000373
# Epoch [3091/4000] Train Loss: 0.000366 Val Loss: 0.000372
# Epoch [3101/4000] Train Loss: 0.000364 Val Loss: 0.000372
# Epoch [3111/4000] Train Loss: 0.000364 Val Loss: 0.000371
# Epoch [3121/4000] Train Loss: 0.000364 Val Loss: 0.000372
# Epoch [3131/4000] Train Loss: 0.000365 Val Loss: 0.000372
# Epoch [3141/4000] Train Loss: 0.000365 Val Loss: 0.000371
# Epoch [3151/4000] Train Loss: 0.000363 Val Loss: 0.000370
# Epoch [3161/4000] Train Loss: 0.000364 Val Loss: 0.000371
# Epoch [3171/4000] Train Loss: 0.000364 Val Loss: 0.000370
# Epoch [3181/4000] Train Loss: 0.000363 Val Loss: 0.000370
# Epoch [3191/4000] Train Loss: 0.000364 Val Loss: 0.000369
# Epoch [3201/4000] Train Loss: 0.000362 Val Loss: 0.000369
# Epoch [3211/4000] Train Loss: 0.000362 Val Loss: 0.000369
# Epoch [3221/4000] Train Loss: 0.000363 Val Loss: 0.000370
# Epoch [3231/4000] Train Loss: 0.000363 Val Loss: 0.000372
# Epoch [3241/4000] Train Loss: 0.000361 Val Loss: 0.000368
# Epoch [3251/4000] Train Loss: 0.000361 Val Loss: 0.000368
# Epoch [3261/4000] Train Loss: 0.000362 Val Loss: 0.000369
# Epoch [3271/4000] Train Loss: 0.000361 Val Loss: 0.000369
# Epoch [3281/4000] Train Loss: 0.000360 Val Loss: 0.000368
# Epoch [3291/4000] Train Loss: 0.000360 Val Loss: 0.000367
# Epoch [3301/4000] Train Loss: 0.000361 Val Loss: 0.000368
# Epoch [3311/4000] Train Loss: 0.000360 Val Loss: 0.000368
# Epoch [3321/4000] Train Loss: 0.000361 Val Loss: 0.000370
# Epoch [3331/4000] Train Loss: 0.000359 Val Loss: 0.000367
# Epoch [3341/4000] Train Loss: 0.000359 Val Loss: 0.000366
# Epoch [3351/4000] Train Loss: 0.000359 Val Loss: 0.000366
# Epoch [3361/4000] Train Loss: 0.000359 Val Loss: 0.000366
# Epoch [3371/4000] Train Loss: 0.000358 Val Loss: 0.000365
# Epoch [3381/4000] Train Loss: 0.000360 Val Loss: 0.000368
# Epoch [3391/4000] Train Loss: 0.000358 Val Loss: 0.000366
# Epoch [3401/4000] Train Loss: 0.000358 Val Loss: 0.000365
# Epoch [3411/4000] Train Loss: 0.000359 Val Loss: 0.000366
# Epoch [3421/4000] Train Loss: 0.000357 Val Loss: 0.000365
# Epoch [3431/4000] Train Loss: 0.000357 Val Loss: 0.000364
# Epoch [3441/4000] Train Loss: 0.000357 Val Loss: 0.000364
# Epoch [3451/4000] Train Loss: 0.000358 Val Loss: 0.000366
# Epoch [3461/4000] Train Loss: 0.000357 Val Loss: 0.000365
# Epoch [3471/4000] Train Loss: 0.000356 Val Loss: 0.000363
# Epoch [3481/4000] Train Loss: 0.000356 Val Loss: 0.000363
# Epoch [3491/4000] Train Loss: 0.000356 Val Loss: 0.000364
# Epoch [3501/4000] Train Loss: 0.000356 Val Loss: 0.000363
# Epoch [3511/4000] Train Loss: 0.000356 Val Loss: 0.000363
# Epoch [3521/4000] Train Loss: 0.000356 Val Loss: 0.000363
# Epoch [3531/4000] Train Loss: 0.000356 Val Loss: 0.000364
# Epoch [3541/4000] Train Loss: 0.000355 Val Loss: 0.000363
# Epoch [3551/4000] Train Loss: 0.000356 Val Loss: 0.000362
# Epoch [3561/4000] Train Loss: 0.000355 Val Loss: 0.000362
# Epoch [3571/4000] Train Loss: 0.000355 Val Loss: 0.000362
# Epoch [3581/4000] Train Loss: 0.000355 Val Loss: 0.000362
# Epoch [3591/4000] Train Loss: 0.000356 Val Loss: 0.000362
# Epoch [3601/4000] Train Loss: 0.000354 Val Loss: 0.000361
# Epoch [3611/4000] Train Loss: 0.000354 Val Loss: 0.000361
# Epoch [3621/4000] Train Loss: 0.000354 Val Loss: 0.000361
# Epoch [3631/4000] Train Loss: 0.000354 Val Loss: 0.000362
# Epoch [3641/4000] Train Loss: 0.000354 Val Loss: 0.000361
# Epoch [3651/4000] Train Loss: 0.000354 Val Loss: 0.000361
# Epoch [3661/4000] Train Loss: 0.000354 Val Loss: 0.000361
# Epoch [3671/4000] Train Loss: 0.000354 Val Loss: 0.000360
# Epoch [3681/4000] Train Loss: 0.000353 Val Loss: 0.000361
# Epoch [3691/4000] Train Loss: 0.000353 Val Loss: 0.000361
# Epoch [3701/4000] Train Loss: 0.000353 Val Loss: 0.000361
# Epoch [3711/4000] Train Loss: 0.000354 Val Loss: 0.000359
# Epoch [3721/4000] Train Loss: 0.000353 Val Loss: 0.000360
# Epoch [3731/4000] Train Loss: 0.000353 Val Loss: 0.000359
# Epoch [3741/4000] Train Loss: 0.000353 Val Loss: 0.000359
# Epoch [3751/4000] Train Loss: 0.000352 Val Loss: 0.000359
# Epoch [3761/4000] Train Loss: 0.000352 Val Loss: 0.000360
# Epoch [3771/4000] Train Loss: 0.000352 Val Loss: 0.000359
# Epoch [3781/4000] Train Loss: 0.000352 Val Loss: 0.000359
# Epoch [3791/4000] Train Loss: 0.000351 Val Loss: 0.000360
# Epoch [3801/4000] Train Loss: 0.000351 Val Loss: 0.000359
# Epoch [3811/4000] Train Loss: 0.000351 Val Loss: 0.000359
# Epoch [3821/4000] Train Loss: 0.000351 Val Loss: 0.000358
# Epoch [3831/4000] Train Loss: 0.000351 Val Loss: 0.000358
# Epoch [3841/4000] Train Loss: 0.000350 Val Loss: 0.000357
# Epoch [3851/4000] Train Loss: 0.000351 Val Loss: 0.000358
# Epoch [3861/4000] Train Loss: 0.000351 Val Loss: 0.000358
# Epoch [3871/4000] Train Loss: 0.000350 Val Loss: 0.000357
# Epoch [3881/4000] Train Loss: 0.000350 Val Loss: 0.000359
# Epoch [3891/4000] Train Loss: 0.000350 Val Loss: 0.000357
# Epoch [3901/4000] Train Loss: 0.000352 Val Loss: 0.000357
# Epoch [3911/4000] Train Loss: 0.000350 Val Loss: 0.000357
# Epoch [3921/4000] Train Loss: 0.000350 Val Loss: 0.000357
# Epoch [3931/4000] Train Loss: 0.000349 Val Loss: 0.000356
# Epoch [3941/4000] Train Loss: 0.000350 Val Loss: 0.000357
# Epoch [3951/4000] Train Loss: 0.000349 Val Loss: 0.000356
# Epoch [3961/4000] Train Loss: 0.000349 Val Loss: 0.000356
# Epoch [3971/4000] Train Loss: 0.000349 Val Loss: 0.000356
# Epoch [3981/4000] Train Loss: 0.000349 Val Loss: 0.000358
# Epoch [3991/4000] Train Loss: 0.000350 Val Loss: 0.000358

# %% [markdown]
# ## Reconstruction on a Sample
#
# To qualitatively verify the training, we select a single validation sample and run the autoencoder to obtain its reconstruction.
# We then compute the reconstruction error (MSE) between the original input and the reconstructed output.

# %%
# -----------------------------
# Sample selection
# -----------------------------
idx = 62

sample = x_val[idx]                    # Shape: (3, H, W)
sample_input = np.expand_dims(sample, axis=0)  # Shape: (1, 3, H, W)

# -----------------------------
# Reconstruction
# -----------------------------
model.eval()

with torch.no_grad():
    sample_tensor = torch.tensor(
        sample_input,
        dtype=torch.float32,
        device=device
    )

    recon = model(sample_tensor)

# zurück zu NumPy
recon = recon.squeeze(0).cpu().numpy()  # (3, H, W)

# -----------------------------
# Reconstruction Error (MSE)
# -----------------------------
mse = np.mean((sample - recon) ** 2)

print(f"Reconstruction MSE: {mse:.6f}")

# -----------------------------
# Visualization
# -----------------------------
sample_img = np.transpose(sample, (1, 2, 0))
recon_img = np.transpose(recon, (1, 2, 0))

fig, axs = plt.subplots(1, 2, figsize=(8, 4))

axs[0].imshow(sample_img)
axs[0].set_title("Original")
axs[0].axis("off")

axs[1].imshow(recon_img)
axs[1].set_title("Reconstruction")
axs[1].axis("off")

plt.tight_layout()
plt.show()
# Out:
# Reconstruction MSE: 0.000300

# %% [markdown]
# ## Saving the Trained Model
#
# To enable reuse and reproducibility, we save the trained autoencoder to disk.
# The saved model can later be loaded for evaluation on anomalous data or for inference in other scripts.

# %%
MODEL_DIR = "../../models"

os.makedirs(MODEL_DIR, exist_ok=True)

model_path = os.path.join(
    MODEL_DIR,
    "ae_bn16_broach_dataset_PyTorch_20260709.pth"
)

torch.save(model.state_dict(), model_path)

print(f"Model saved to: {model_path}")
# Out:
# Model saved to: ../models\ae_bn16_broach_dataset_PyTorch_20260709.pth

# %%
plt.figure(figsize=(10, 5))

plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')

plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Reconstruction Error during Training')

plt.legend()
plt.tight_layout()

plt.show()

# %%
print(f"Final Train Loss: {train_losses[-1]:.6f}")
print(f"Final Val Loss:   {val_losses[-1]:.6f}")
print(f"Best Val Loss:    {min(val_losses):.6f}")
# Out:
# Final Train Loss: 0.000349
# Final Val Loss:   0.000356
# Best Val Loss:    0.000356
