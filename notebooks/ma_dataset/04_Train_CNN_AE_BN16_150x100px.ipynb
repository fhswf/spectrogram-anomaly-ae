# %% [markdown]
# # Autoencoder Training
#
# This notebook trains a convolutional autoencoder on **normal data** (no chatter).
# The model learns a compact representation and attempts to reconstruct the input images.
# Because anomalous samples (chatter) are not seen during training, we expect them to yield a **higher reconstruction error**.
#
# **Core idea:** anomaly score = reconstruction error (e.g., MSE) between the input and its reconstruction.

# %%
import os
import random
import numpy as np
import tensorflow as tf
from PIL import Image
from tqdm import tqdm
import plotly.express as px 
import os
from pathlib import Path

from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.layers import Dense, Flatten, Reshape
import matplotlib.pyplot as plt
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782896375.972453  882243 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1782896376.023488  882243 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782896379.887089  882243 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# =========================
# Reproducibility (Seeds)
# =========================
SEED = 42

os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# =========================
# GPU check (optional)
# =========================
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"TensorFlow detects {len(gpus)} GPU(s):")
    for gpu in gpus:
        print("-", gpu)
else:
    print("No GPU found.")
# Out:
# No GPU found.
# E0000 00:00:1782896381.786086  882243 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# ## Data
#
# The spectrograms are loaded as images.
#
# We distinguish between:
# - **GOOD / Normal**: samples without chatter (used for training)
# - **BAD / Chatter**: potentially anomalous samples (typically used for evaluation)
#
# This notebook trains the autoencoder using **only the normal (GOOD)** class.

# %%
#DATA_GOOD = "../data/02_spectrograms_150x100px_dataset/train/no_chatter"
DATA_GOOD = "../../data/03_ma_dataset/train/"

# %%
def load_images_from_folder(folder, target_size=(150, 100)):
    """
    Load all images from a folder, resize them to target_size,
    convert to RGB, and return a NumPy array of shape (N, H, W, C).
    """
    images = []
    valid_ext = ('.png', '.jpg', '.jpeg')

    for file in tqdm(os.listdir(folder)):
        if file.lower().endswith(valid_ext):
            path = os.path.join(folder, file)
            img = Image.open(path).convert("RGB").resize(target_size)
            images.append(np.array(img))

    return np.array(images)

# %% [markdown]
# Load only normal data!

# %%
images = load_images_from_folder(DATA_GOOD)

# Normalize to [0, 1]
images = images.astype("float32") / 255.0
print("Loaded normal samples:", images.shape)

# Split into training and validation sets (only normal data)
x_train, x_val = train_test_split(
    images,
    test_size=0.2,
    random_state=SEED,
    shuffle=True
)

print("Train:", x_train.shape)
print("Val:", x_val.shape)
# Out:
# 100%|██████████| 5000/5000 [00:41<00:00, 121.26it/s]
# Loaded normal samples: (5000, 100, 150, 3)
# Train: (4000, 100, 150, 3)
# Val: (1000, 100, 150, 3)

# %% [markdown]
# ## Visualization / Sanity Check
#
# To verify the data pipeline, we visualize one example spectrogram from the training set.
# This helps confirm that resizing and normalization behave as expected.

# %%
fig = px.imshow(x_train[1120])
fig.update_layout(coloraxis_showscale=False)
fig.show()

# %% [markdown]
# ## Model: Convolutional Autoencoder
#
# The autoencoder consists of three parts:
#
# 1. **Encoder**: extracts features using convolutions and progressively reduces spatial dimensions
# 2. **Bottleneck**: compresses the representation using a dense layer
# 3. **Decoder**: reconstructs the input via dense expansion, reshaping, upsampling, and convolutions
#
# ### Training objective
# The model minimizes the reconstruction error (MSE) between the input image $x$ and its reconstruction $\hat{x}$.
#
# During anomaly detection, the reconstruction error is used as an anomaly score.

# %%
input_shape = (100, 150, 3)

# Sequential-Modell
autoencoder = Sequential()

# ---- Encoder ----
autoencoder.add(Conv2D(4, (3, 3), activation='relu', padding='same', input_shape=input_shape))
autoencoder.add(MaxPooling2D((2, 2), padding='same'))  

autoencoder.add(Conv2D(8, (3, 3), activation='relu', padding='same'))  
autoencoder.add(MaxPooling2D((2, 3), padding='same')) 

autoencoder.add(Conv2D(12, (3, 3), activation='relu', padding='same')) 

# ---- Bottleneck ----
autoencoder.add(Flatten()) 
autoencoder.add(Dense(16, activation='relu'))  # compact latent representation

# ---- Decoder ----
autoencoder.add(Dense(25 * 25 * 12, activation='relu'))  
autoencoder.add(Reshape((25, 25, 12)))  
autoencoder.add(Conv2D(12, (3, 3), activation='relu', padding='same')) 

autoencoder.add(UpSampling2D((2, 3)))  
autoencoder.add(Conv2D(8, (3, 3), activation='relu', padding='same')) 

autoencoder.add(UpSampling2D((2, 2))) 
autoencoder.add(Conv2D(4, (3, 3), activation='relu', padding='same'))

autoencoder.add(Conv2D(3, (3, 3), activation='sigmoid', padding='same'))
# Out:
# /home/cgawron/git/spectrogram-anomaly-ae/.venv/lib/python3.13/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Training Setup
#
# - **Optimizer:** Adam with a small learning rate
# - **Loss:** Mean Squared Error (MSE), measuring reconstruction quality
#
# Because the autoencoder is trained on normal data only, anomalous inputs are expected to produce larger reconstruction errors.

# %%
autoencoder.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='mse'
)

autoencoder.summary()

history = autoencoder.fit(
    x_train, x_train,  # Autoencoder target is the input itself
    epochs=4000,
    batch_size=512,
    validation_data=(x_val, x_val),
    shuffle=True
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 100, 150, 4)    │           112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 50, 75, 4)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 50, 75, 8)      │           296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 25, 25, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 25, 25, 12)     │           876 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 7500)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │       120,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7500)           │       127,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 25, 25, 12)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 25, 25, 12)     │         1,308 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 50, 75, 12)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 50, 75, 8)      │           872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 100, 150, 8)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 100, 150, 4)    │           292 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 100, 150, 3)    │           111 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 251,383 (981.96 KB)
#  Trainable params: 251,383 (981.96 KB)
#  Non-trainable params: 0 (0.00 B)
# W0000 00:00:1782896526.955322  882243 cpu_allocator_impl.cc:82] Allocation of 720000000 exceeds 10% of free system memory.
# Epoch 1/4000
# W0000 00:00:1782896527.273127  882243 cpu_allocator_impl.cc:82] Allocation of 720000000 exceeds 10% of free system memory.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.2332 - val_loss: 0.2328
# Epoch 2/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 978ms/step - loss: 0.2328 - val_loss: 0.2324
# Epoch 3/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 970ms/step - loss: 0.2324 - val_loss: 0.2320
# Epoch 4/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 967ms/step - loss: 0.2318 - val_loss: 0.2314
# Epoch 5/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 985ms/step - loss: 0.2311 - val_loss: 0.2304
# Epoch 6/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 981ms/step - loss: 0.2298 - val_loss: 0.2285
# Epoch 7/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 978ms/step - loss: 0.2272 - val_loss: 0.2246
# Epoch 8/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 980ms/step - loss: 0.2221 - val_loss: 0.2177
# Epoch 9/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 973ms/step - loss: 0.2135 - val_loss: 0.2071
# Epoch 10/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 989ms/step - loss: 0.2022 - val_loss: 0.1957
# Epoch 11/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 985ms/step - loss: 0.1918 - val_loss: 0.1866
# Epoch 12/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 984ms/step - loss: 0
4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1072/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1073/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1074/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1075/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1076/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1077/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1078/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1079/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1080/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1081/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1082/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1083/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1084/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1085/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1086/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1087/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1088/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1089/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1090/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1091/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1092/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1093/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1094/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1095/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1096/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1097/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1098/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1099/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1100/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1101/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1102/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1103/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1104/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1105/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1106/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1107/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1108/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1109/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1110/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1111/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1112/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1113/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1114/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1115/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1116/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1117/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1118/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1119/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1120/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1121/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1122/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1123/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1124/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1125/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1126/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1127/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1128/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1129/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1130/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1131/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1132/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1133/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1134/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1135/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1136/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1137/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1138/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1139/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1140/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1141/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1142/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1143/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1144/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1145/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1146/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1147/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1148/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1149/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1150/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1151/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1152/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1153/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1154/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1155/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1156/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1157/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1158/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1159/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1160/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1161/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1162/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1163/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1164/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1165/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1166/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1167/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1168/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1169/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1170/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1171/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1172/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1173/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1174/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1175/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1176/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1000ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1177/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1178/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1179/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1180/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1181/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1182/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1183/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1184/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1000ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1185/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1186/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1187/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1188/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1189/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1190/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1191/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1192/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1193/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1194/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1195/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1196/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1197/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1198/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1199/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 998ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1200/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1201/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1202/4000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 1203/4000

# %% [markdown]
# ## Reconstruction on a Sample
#
# To qualitatively verify the training, we select a single validation sample and run the autoencoder to obtain its reconstruction.
# We then compute the reconstruction error (MSE) between the original input and the reconstructed output.

# %%
# -----------------------------
# Sample selection
# -----------------------------
idx = 62  # choose any index in the validation set
sample = x_val[idx]
sample_input = np.expand_dims(sample, axis=0)  # shape: (1, H, W, C)

# -----------------------------
# Reconstruction
# -----------------------------
recon = autoencoder.predict(sample_input, verbose=0)[0]

# -----------------------------
# Reconstruction Error (MSE)
# -----------------------------
mse = np.mean((sample - recon) ** 2)
print(f"Reconstruction MSE: {mse:.6f}")

# -----------------------------
# Visualization: original vs reconstruction
# -----------------------------
fig, axs = plt.subplots(1, 2, figsize=(8, 4))

axs[0].imshow(sample)
axs[0].set_title("Original")
axs[0].axis("off")

axs[1].imshow(recon)
axs[1].set_title("Reconstruction")
axs[1].axis("off")

plt.tight_layout()
plt.show()
# Out:
# Reconstruction MSE: 0.000288

# %% [markdown]
# ## Saving the Trained Model
#
# To enable reuse and reproducibility, we save the trained autoencoder to disk.
# The saved model can later be loaded for evaluation on anomalous data or for inference in other scripts.

# %%
MODEL_DIR = Path("../models")
MODEL_DIR.mkdir(parents=True, exist_ok=True)

model_path = MODEL_DIR / "ae_bn16_ma_dataset_20260618.keras"

# -----------------------------
# Save the trained model
# -----------------------------
autoencoder.save(model_path)

print(f"Model saved to: {model_path}")
# Out:
# Model saved to: ..\models\ae_bn16_2ma_dataset_0260618.keras

# %%
plt.figure(figsize=(10, 5))

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Reconstruction Error during Training')
plt.legend()
plt.tight_layout()
plt.show()

# %%
print("Final Train Loss:", history.history['loss'][-1])
print("Final Val Loss:", history.history['val_loss'][-1])
# Out:
# Final Train Loss: 0.0003175065212417394
# Final Val Loss: 0.0003227210254408419
