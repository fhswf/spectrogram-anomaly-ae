# %% [markdown]
# # 10 Error Analysis and Deployment Benchmark
#
# Inspect false positives/false negatives and benchmark inference time and memory footprint.

# %%
from pathlib import Path
import platform
import time
import pandas as pd

REPO_ROOT = Path('..').resolve()
ERROR_DIR = REPO_ROOT / 'reports' / 'error_analysis'
BENCHMARK_DIR = REPO_ROOT / 'reports' / 'benchmarks'
ERROR_DIR.mkdir(parents=True, exist_ok=True)
BENCHMARK_DIR.mkdir(parents=True, exist_ok=True)
benchmark_context = {
    'platform': platform.platform(),
    'python': platform.python_version(),
}
benchmark_context

# %% [markdown]
# ## Experiment Steps
#
# Fill in the executable experiment cells here. Outputs should be written under reports/ so later notebooks can consume them.
